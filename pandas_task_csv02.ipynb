# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/Data-Analatics/blob/main/pandas_task_csv02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv(r'/content/Coffee_sales_uncleaned.csv')
data
# Out:
#      hour_of_day cash_type         money    coffee_name Time_of_Day Weekday  \
# 0           10.0      card  thirty eight          Latte     Morning     Fri
# 1         twelve      card           NaN  Hot Chocolate   Afternoon     Fri
# 2           12.0      card          38.7         lattee   Afternoon     Fri
# 3            NaN      card          28.9      Americano   Afternoon     Fri
# 4           13.0      card          38.7          Latte   Afternoon     Fri
# ...          ...       ...           ...            ...         ...     ...
# 3542        10.0      card         35.76     Cappuccino     Morning     Sun
# 3543        14.0      card         35.76          Cocoa   Afternoon     Sun
# 3544        14.0      card         35.76          Cocoa         NaN     NaN
# 3545        15.0      card         25.96      Americano   Afternoon     Sun
# 3546        18.0      card         35.76          Latte       Night     Sun
#
# ...

# %%
(1) #Convert the hour_of_day column to integer type (handle strings like "twelve").
data["hour_of_day"] = df["hour_of_day"].replace("twelve", 12)
data["hour_of_day"] = pd.to_numeric(df["hour_of_day"], errors="coerce").astype("Int64")

# %%
(2)
data["money"] = df["money"].replace("thirty eight", 38)
data["money"] = pd.to_numeric(df["money"], errors="coerce")

# %%
(3)
data["Data"]=pd.to_datetime(df["Date"],errors="coerce")

# %%
(4)
data.shape
# Out:
# (3547, 11)

# %%
(5)
data_clean = df.dropna()
data_clean.shape
# Out:
# (797, 11)

# %%
(6)
data["new_column"] = 0
data.shape
# Out:
# (3547, 13)

# %%
(7) #describe()
data.describe()
# Out:
#        hour_of_day        money  Weekdaysort    Monthsort  \
# count       3370.0  3370.000000  3370.000000  3370.000000
# mean     14.191988    31.656297     3.846291     6.440059
# min            6.0    18.120000     1.000000     1.000000
# 25%           10.0    27.920000     2.000000     3.000000
# 50%           14.0    32.820000     4.000000     7.000000
# 75%           18.0    35.760000     6.000000    10.000000
# max           22.0    38.700000     7.000000    12.000000
# std       4.235596     4.880474     1.973284     3.497715
#
#                                 Date                           Data  \
# count                           1337                           1337
# mean   2024-10-09 18:34:44.068810752  2024-10-09 18:34:44.068810752
# min              2024-01-03 00:00:00            2024-01-03 00:00:00
# 25%              2024-05-08 00:00:00            2024-05-08 00:00:00
# 50%              2024-09-07 00:00:00            2024-09-07 00:00:00
# ...

# %%
(8) #categorical ststistics
data.describe(include="object")
# Out:
#        cash_type          coffee_name Time_of_Day Weekday Month_name     Time
# count       3370                 3371        3370    3370       3370     3370
# unique         2                    9           3       7         12     3209
# top         card  Americano with Milk   Afternoon     Tue        Mar  17:38.7
# freq        3369                  761        1150     540        468        3

# %%
(9) #compare before and after cleaning
print("Before:")
print(df.describe())

print("After:")
print(data_clean.describe())
# Out:
# Before:
#        hour_of_day        money  Weekdaysort    Monthsort  \
# count       3370.0  3370.000000  3370.000000  3370.000000
# mean     14.191988    31.656297     3.846291     6.440059
# min            6.0    18.120000     1.000000     1.000000
# 25%           10.0    27.920000     2.000000     3.000000
# 50%           14.0    32.820000     4.000000     7.000000
# 75%           18.0    35.760000     6.000000    10.000000
# max           22.0    38.700000     7.000000    12.000000
# std       4.235596     4.880474     1.973284     3.497715
#
#                                 Date
# count                           1337
# mean   2024-10-09 18:34:44.068810752
# min              2024-01-03 00:00:00
# 25%              2024-05-08 00:00:00
# 50%              2024-09-07 00:00:00
# 75%              2025-03-02 00:00:00
# max              2025-12-03 00:00:00
# std                              NaN
# After:
#        hour_of_day       money  Weekdaysort   Monthsort  \
# ...

# %%
(10) #extract coffee_name as a series
coffee = df["coffee_name"]

print(type(coffee))
# Out:
# <class 'pandas.core.series.Series'>

# %%
(11) #count unique coffee names
df["coffee_name"].nunique()
# Out:
# 9

# %%
(12) # first 10 weekday
df["Weekday"].head(10)
# Out:
# 0    Fri
# 1    Fri
# 2    Fri
# 3    Fri
# 4    Fri
# 5    Fri
# 6    Fri
# 7    Fri
# 8    Fri
# 9    Fri
# Name: Weekday, dtype: object

# %%
(13) #cash_type frequency
df["cash_type"].value_counts()
# Out:
# cash_type
# card     3369
# CARD        1
# Name: count, dtype: int64

# %%
(13) # 'card','card'
print(df["cash_type"].unique())
# Out:
# ['card' 'CARD ' nan]

# %%
df["cash_type"] = df["cash_type"].str.strip().str.lower()

print(df["cash_type"].value_counts())
# Out:
# cash_type
# card    3370
# Name: count, dtype: int64

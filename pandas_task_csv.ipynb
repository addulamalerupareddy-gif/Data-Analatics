# %% [markdown]
# <a href="https://colab.research.google.com/github/addulamalerupareddy-gif/Data-Analatics/blob/main/pandas_task_csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('/content/sales_data_uncleaned.csv')
data
# Out:
#    OrderID        Date   CustomerName     Product     Category  Quantity  \
# 0     1001  05-01-2024       John Doe      Laptop  Electronics       1.0
# 1     1002  06-01-2024     Jane Smith      Mobile  Electronics       2.0
# 2     1003  07-01-2024            NaN       Shoes      Fashion       3.0
# 3     1004  07-01-2024    Emily Davis     T-shirt      Fashion       2.0
# 4     1005  08-01-2024  Michael Brown  Headphones  Electronics       1.0
# 5     1006  08-01-2024    Chris Green      Laptop  Electronics       NaN
# 6     1007  09-01-2024      Sarah Lee       Shoes      Fashion       1.0
# 7     1008  10-01-2024   David Wilson      Laptop  Electronics       1.0
# 8     1009  10-01-2024   Linda Taylor     T-shirt      Fashion       2.0
# 9     1010  11-01-2024       John Doe         NaN  Electronics       1.0
#
#    Price   Total         City
# 0    800     NaN     New York
# 1    500  1000.0  los angeles
# 2     50   150.0      Chicago
# 3     25    50.0       Boston
# ...

# %%
(2) #loan dataset
data=pd.read_csv('/content/sales_data_uncleaned.csv')
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
(3) #first 5 rows
data.head()
# Out:
#    OrderID        Date   CustomerName     Product     Category  Quantity  \
# 0     1001  05-01-2024       John Doe      Laptop  Electronics       1.0
# 1     1002  06-01-2024     Jane Smith      Mobile  Electronics       2.0
# 2     1003  07-01-2024            NaN       Shoes      Fashion       3.0
# 3     1004  07-01-2024    Emily Davis     T-shirt      Fashion       2.0
# 4     1005  08-01-2024  Michael Brown  Headphones  Electronics       1.0
#
#    Price   Total         City
# 0    800     NaN     New York
# 1    500  1000.0  los angeles
# 2     50   150.0      Chicago
# 3     25    50.0       Boston
# 4    100   100.0     new york

# %%
(4) #specific columns
data[["CustomerName","Product","Total"]]
# Out:
#     CustomerName     Product   Total
# 0       John Doe      Laptop     NaN
# 1     Jane Smith      Mobile  1000.0
# 2            NaN       Shoes   150.0
# 3    Emily Davis     T-shirt    50.0
# 4  Michael Brown  Headphones   100.0
# 5    Chris Green      Laptop     NaN
# 6      Sarah Lee       Shoes    55.0
# 7   David Wilson      Laptop   850.0
# 8   Linda Taylor     T-shirt     NaN
# 9       John Doe         NaN   200.0

# %%
(5) #display missing values as "Missing"
data=pd.read_csv('/content/sales_data_uncleaned.csv').fillna("Missing")

# %% [markdown]
# Basic Inspection

# %%
(6)
data.head(7) #first 7 rows
# Out:
#    OrderID        Date   CustomerName     Product     Category Quantity  \
# 0     1001  05-01-2024       John Doe      Laptop  Electronics      1.0
# 1     1002  06-01-2024     Jane Smith      Mobile  Electronics      2.0
# 2     1003  07-01-2024        Missing       Shoes      Fashion      3.0
# 3     1004  07-01-2024    Emily Davis     T-shirt      Fashion      2.0
# 4     1005  08-01-2024  Michael Brown  Headphones  Electronics      1.0
# 5     1006  08-01-2024    Chris Green      Laptop  Electronics  Missing
# 6     1007  09-01-2024      Sarah Lee       Shoes      Fashion      1.0
#
#    Price    Total         City
# 0    800  Missing     New York
# 1    500   1000.0  los angeles
# 2     50    150.0      Chicago
# 3     25     50.0       Boston
# 4    100    100.0     new york
# 5    800  Missing  Los Angeles
# 6     55     55.0      Chicago

# %%
(7) #last 3 rows
data.tail(3)
# Out:
#    OrderID        Date  CustomerName  Product     Category Quantity  Price  \
# 7     1008  10-01-2024  David Wilson   Laptop  Electronics      1.0    850
# 8     1009  10-01-2024  Linda Taylor  T-shirt      Fashion      2.0     25
# 9     1010  11-01-2024      John Doe  Missing  Electronics      1.0    200
#
#      Total         City
# 7    850.0  LOS ANGELES
# 8  Missing       Boston
# 9    200.0     New York

# %%
(8) #number of rows and columns
data.shape
# Out:
# (10, 9)

# %%
(9) #column names
data.columns.tolist()
# Out:
# ['OrderID',
#  'Date',
#  'CustomerName',
#  'Product',
#  'Category',
#  'Quantity',
#  'Price',
#  'Total',
#  'City']

# %%
(10) #data types
data.dtypes
# Out:
# OrderID          int64
# Date            object
# CustomerName    object
# Product         object
# Category        object
# Quantity        object
# Price            int64
# Total           object
# City            object
# dtype: object

# %% [markdown]
# SUMMARY & METADATA

# %%
(11) #duplicate orderid
data.index.duplicated().any()
# Out:
# np.False_

# %%
(12) #information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       10 non-null     int64
#  1   Date          10 non-null     object
#  2   CustomerName  10 non-null     object
#  3   Product       10 non-null     object
#  4   Category      10 non-null     object
#  5   Quantity      10 non-null     object
#  6   Price         10 non-null     int64
#  7   Total         10 non-null     object
#  8   City          10 non-null     object
# dtypes: int64(2), object(7)
# memory usage: 852.0+ bytes

# %%
(13) #numerical summary
data.describe()
# Out:
#           OrderID      Price
# count    10.00000   10.00000
# mean   1005.50000  340.50000
# std       3.02765  357.44036
# min    1001.00000   25.00000
# 25%    1003.25000   51.25000
# 50%    1005.50000  150.00000
# 75%    1007.75000  725.00000
# max    1010.00000  850.00000

# %%
(14) #categorical summary
data.describe(include="object")
# Out:
#               Date CustomerName Product     Category  Quantity    Total  \
# count           10           10      10           10      10.0       10
# unique           7            9       6            2       4.0        8
# top     07-01-2024     John Doe  Laptop  Electronics       1.0  Missing
# freq             2            2       3            6       5.0        3
#
#             City
# count         10
# unique         7
# top     New York
# freq           2

# %%
(15) #max and min price
print('Maximum:',data['Price'].max())
print('Minimum:',data['Price'].min())
# Out:
# Maximum: 850
# Minimum: 25

# %% [markdown]
# Exploration

# %%
(16) #number of unique customers
data["CustomerName"].nunique()
# Out:
# 9

# %%
(17) #unique categories
data["Category"].unique()
# Out:
# array(['Electronics', 'Fashion'], dtype=object)

# %%
(18) #product frequnecy
data['Product'].value_counts()
# Out:
# Product
# Laptop        3
# Shoes         2
# T-shirt       2
# Mobile        1
# Headphones    1
# Missing       1
# Name: count, dtype: int64

# %%
(19) #city frequency
data['City'].value_counts()
# Out:
# City
# New York       2
# Chicago        2
# Boston         2
# los angeles    1
# new york       1
# Los Angeles    1
# LOS ANGELES    1
# Name: count, dtype: int64

# %%
(20) #null values
data.isnull().sum()
# Out:
# OrderID         0
# Date            0
# CustomerName    0
# Product         0
# Category        0
# Quantity        0
# Price           0
# Total           0
# City            0
# dtype: int64
